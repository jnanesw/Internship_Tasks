# %%
# !pip install pymongo[srv]

# %%
import pymongo
import requests
from bs4 import BeautifulSoup as BS

# %%
client = pymongo.MongoClient("mongodb+srv://JnaneswarRao:MongoDb@cluster0.b16ec.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.b16ec.mongodb.net:27017', 'cluster0-shard-00-02.b16ec.mongodb.net:27017', 'cluster0-shard-00-01.b16ec.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-tcb6r5-shard-0', tls=True), 'test')

# %%
db1=client["Stamurai"]

# %%
coll1=db1["FCPS"]

# %% [markdown]
# # FCPS

# %%
def deCFEmail(fp):
    try:
        r = int(fp[:2],16)
        email = ''.join([chr(int(fp[i:i+2], 16) ^ r) for i in range(2, len(fp), 2)])
        return email
    except (ValueError):
        pass

# %%
for i in range(0,28):
    url="https://www.fcps.edu/schools-centers?items_per_page=10&keywords=&page="
    url=url+str(i)
    req=requests.get(url)
    req.encoding="utf-8"
    response=BS(req.content,"html.parser")
    extract_info = response.findAll("div",{"class":"view__row"})
    
    
    for j in range(0,len(extract_info)):
        inside_extracted_info = extract_info[j].article
        Actual_info = inside_extracted_info.findAll("div",{"class":"node__section"})
        
        Name_of_College = Actual_info[0].div.a.text.replace("\n","")
        Address_And_phoneNumber_of_College = Actual_info[1].text.replace("\n"," ")

        E_mail=""
        Designation=""
        Name=""
        if(Actual_info[2].a):
            E_mail = Actual_info[2].a.get("href").replace("/cdn-cgi/l/email-protection#","")
            E_mail=deCFEmail(E_mail)
            
            Name=Actual_info[2].a.text
            
            Designation=Actual_info[2].div.div.text
            
        if(E_mail==""):
            E_mail="Not Provided"
            Designation="Not Provided"
            Name="Not Provided"
        
        dict1={
            "Name of the college":Name_of_College,
            "Address and phone Number":Address_And_phoneNumber_of_College,
            "Name":Name,
            "Designation":Designation,
            "E-Mail":E_mail
        }
        coll1.insert_one(dict1)
        
        print(i)
        print("Name of the college: "+Name_of_College)
        print("Address and phone Number: "+Address_And_phoneNumber_of_College)
        print("Name: "+Name)
        print("Designation: "+Designation)
        print("E-Mail: "+E_mail)
        print("\n")
# Out:
# 0
# Name of the college: Adult and Community Education (ACE)
# Address and phone Number:    Adult ESOL and Registration Offices 6815 Edsall Rd Springfield, VA 22151   Adult Community Education Administrative Offices 7510 Lisle Avenue Falls Church, VA 22043    703-658-2727
# Name: Not Provided
# Designation: Not Provided
# E-Mail: Not Provided
#
#
# 0
# Name of the college: Aldrin Elementary School
# Address and phone Number:    11375 Center Harbor Rd Reston, VA 20194    703-904-3800
# Name: Shane Wolfe
#
# Designation: Principal
# E-Mail: shane.wolfe@fcps.edu
#
#
# 0
# Name of the college: Annandale High School
# Address and phone Number:    4700 Medford Dr Annandale, VA 22003    703-642-4100
# Name: Shawn DeRose
#
# Designation: Principal
# E-Mail: spderose@fcps.edu
#
#
# 0
# Name of the college: Annandale Terrace Elementary School
# Address and phone Number:    7604 Herald St Annandale, VA 22003    703-658-5600
# Name: Ingrid Badía
#
# Designation: Principal
# ...

# %% [markdown]
# # Miami

# %%
coll2=db1["Miami"]

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By

# %%
driver=Chrome(executable_path="C:\WebDrivers\chromedriver.exe")
driver.maximize_window()
driver.get("https://www3.dadeschools.net/SchoolInformation/home")
driver.implicitly_wait(10)

All_items=driver.find_element(By.XPATH, "//select[contains(@name,'perPage')]/option[contains(@value,'4: 1000000')]")
All_items.click()

tr=driver.find_elements(By.XPATH,"//tr[contains(@class,'ng-star-inserted')]")
j=1
for i in tr:
    
    td=i.find_elements(By.TAG_NAME,"td")
    Name = td[3].text.replace("\n","")
    E_Mail = td[0].find_element(By.TAG_NAME,"a").get_attribute("href").replace("mailto:","")
    Address = td[1].text.replace("\n","")
    Phone_Number = td[2].text
    
    dict2={
        "Name":Name,
        "E-Mail":E_Mail,
        "Address":Address,
        "Phone_Number":Phone_Number
    }
    coll2.insert_one(dict2)
    
    print(j)
    print("Name: "+Name)
    print("E-Mail: "+E_Mail)
    print("Address: "+Address)
    print("Phone_Number: "+Phone_Number)
    print("\n")
    j=j+1
# Out:
# C:\Users\nanim\AppData\Local\Temp\ipykernel_42824\2685610999.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=Chrome(executable_path="C:\WebDrivers\chromedriver.exe")
# 1
# Name: CARMEN M. GARCIA
# E-Mail: pr3191@dadeschools.net
# Address: ADA MERRITT K-8 CENTER660 SW 3 STREETMIAMI, FL 33130
# Phone_Number: (305)326-0791
#
#
# 2
# Name:
# E-Mail: pr9778@dadeschools.net
# Address: ADVANCED COMPUTER PROJECT13135 SW 26 STREETMIAMI, FL 33175
# Phone_Number: (305)995-7616
#
#
# 3
# Name: CISELY J. SCOTT
# E-Mail: pr4071@dadeschools.net
# Address: AGENORIA S. PASCHAL/OLINDA ES5536 NW 21ST AVENUEMIAMI, FL 33142
# Phone_Number: (305)633-0308
#
#
# 4
# Name: ALONZA PENDERGRASS III
# E-Mail: pr0041@dadeschools.net
# Address: AIR BASE K-8 CENTER FOR INTERNATIONAL EDUCATION12829 SW 272ND STREETMIAMI, FL 33032
# Phone_Number: (305)258-3676
#
#
# 5
# Name: CHRISTOPHER J. SHINN
# E-Mail: pr7048@dadeschools.net
# ...
